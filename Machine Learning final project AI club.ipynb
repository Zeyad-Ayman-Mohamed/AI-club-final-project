# %%
#logistic regression
import pandas as pd
# reading csv files
#data =  pd.read_fwf(r'C:\Users\Zeiad\Downloads\iris.data', names=["col1", "col2","col3","col4"])
#print(print(data.columns))
#Iris-setosa will be given 0
#Iris-versicolor will be given 1
#Iris-virginica will be given 2

columns = ['sepal length','sepal width','petal length','petal width','type']
data =pd.read_csv(r'C:\Users\Zeiad\Downloads\iris.data', sep=',', names  = columns)
features = ['sepal length','sepal width','petal length','petal width']
label = ['type']
x= data[features]
y = data[label]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)
#print(x)
# import the class
from sklearn.linear_model import LogisticRegression

# instantiate the model (using the default parameters)
logreg = LogisticRegression()

# fit the model with data
logreg.fit(x_train,y_train)

#
y_pred=logreg.predict(x_test)

from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.868421052631579
# C:\Users\Zeiad\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Zeiad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Zeiad\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
#naive bayes
import pandas as pd
from csv import reader
columns = ['sepal length','sepal width','petal length','petal width','type']
data =pd.read_csv(r'C:\Users\Zeiad\Downloads\iris.data', sep=',', names  = columns)
data_new = data.T
#features
sepal_length = data_new.iloc[0]
sepal_length = tuple(sepal_length)
sepal_width = data_new.iloc[1]
sepal_width = tuple(sepal_width)
petal_length = data_new.iloc[2]
petal_length = tuple(petal_length)
petal_width = data_new.iloc[3]
petal_width = tuple(petal_width)
#label 
speices = data_new.iloc[4]
speices = tuple(speices)


#please take note the file i am working on i already preprocessed before using and encoded the labels in the file
#Iris-setosa will be given 0
#Iris-versicolor will be given 1
#Iris-virginica will be given 2
features=tuple(zip(sepal_length,sepal_width,petal_length,petal_width))
#print(features)

from sklearn.naive_bayes import GaussianNB

#Create a Gaussian Classifier
model = GaussianNB()

# Train the model using the training sets
model.fit(features,speices)

#Predict Output
predicted= model.predict([[5.1,3.5,1.4,0.2]])
print ("Predicted Value:", predicted)
# Out:
# Predicted Value: [0.]

# %%
#naive bayes
import pandas as pd
#Iris-setosa will be given 0
#Iris-versicolor will be given 1
#Iris-virginica will be given 2

columns = ['sepal length','sepal width','petal length','petal width','type']
data =pd.read_csv(r'C:\Users\Zeiad\Downloads\iris.data', sep=',', names  = columns)
features = ['sepal length','sepal width','petal length','petal width']
label = ['type']
x= data[features]
y = data[label]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=109)
from sklearn.naive_bayes import GaussianNB

#Create a Gaussian Classifier
gnb = GaussianNB()

#Train the model using the training sets
gnb.fit(x_train, y_train)

#Predict the response for test dataset
y_pred = gnb.predict(x_test)

from sklearn import metrics

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9555555555555556
# C:\Users\Zeiad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#SVM
import pandas as pd
columns = ['sepal length','sepal width','petal length','petal width','type']
data =pd.read_csv(r'C:\Users\Zeiad\Downloads\iris.data', sep=',', names  = columns)
features = ['sepal length','sepal width','petal length','petal width']
label = ['type']
x= data[features]
y = data[label]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=109)
#Import svm model
from sklearn import svm

#Create a svm Classifier
clf = svm.SVC(kernel='linear') # Linear Kernel

#Train the model using the training sets
clf.fit(x_train, y_train)

#Predict the response for test dataset
y_pred = clf.predict(x_test)
from sklearn import metrics

# Model Accuracy: how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9555555555555556
# C:\Users\Zeiad\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#decision tree
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

columns = ['sepal length','sepal width','petal length','petal width','type']
data =pd.read_csv(r'C:\Users\Zeiad\Downloads\iris.data', sep=',', names  = columns)
features = ['sepal length','sepal width','petal length','petal width']
label = ['type']
x= data[features]
y = data[label]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(x_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(x_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9555555555555556

# %%
#neural network
import pandas as pd
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

columns = ['sepal length','sepal width','petal length','petal width','type']
data =pd.read_csv(r'C:\Users\Zeiad\Downloads\iris.data', sep=',', names  = columns)
features = ['sepal length','sepal width','petal length','petal width']
label = ['type']
x= data[features]
y = data[label]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

from keras import models 
from keras import layers
def build_model():   
    model = models.Sequential()
    model.add(layers.Dense(64, activation='relu',
                           input_shape=(x_train.shape[1],)))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(1))
    model.compile(optimizer='Adam', loss='mse', metrics=['mae'])
    return model
# validation split
x_val = x_train[:40]
partial_x_train = x_train[40:] 
y_val = y_train[:40]
partial_y_train = y_train[40:]
model = build_model()
history = model.fit(partial_x_train,                     
                    partial_y_train,
                    epochs=50,          
                    batch_size=16,
                    validation_data=(x_val, y_val))
# Out:
# Train on 65 samples, validate on 40 samples
# Epoch 1/50
# 65/65 [==============================] - 0s 2ms/step - loss: 5.9297 - mae: 2.2500 - val_loss: 3.0159 - val_mae: 1.5368
# Epoch 2/50
# 65/65 [==============================] - 0s 107us/step - loss: 1.7898 - mae: 1.1078 - val_loss: 0.6202 - val_mae: 0.6716
# Epoch 3/50
# 65/65 [==============================] - 0s 108us/step - loss: 0.3347 - mae: 0.4872 - val_loss: 0.2577 - val_mae: 0.4355
# Epoch 4/50
# 65/65 [==============================] - 0s 123us/step - loss: 0.3183 - mae: 0.4898 - val_loss: 0.4019 - val_mae: 0.5410
# Epoch 5/50
# 65/65 [==============================] - 0s 107us/step - loss: 0.4734 - mae: 0.6044 - val_loss: 0.3816 - val_mae: 0.5382
# Epoch 6/50
# 65/65 [==============================] - 0s 184us/step - loss: 0.3869 - mae: 0.5504 - val_loss: 0.2059 - val_mae: 0.3958
# Epoch 7/50
# 65/65 [==============================] - 0s 107us/step - loss: 0.2086 - mae: 0.4055 - val_loss: 0.1012 - val_mae: 0.2921
# ...
